# %%
# проверка связи)))) шутка ^_^ connection check, joke
a = 1
while a < 5:
    a+= 1
a
# Out:
# 5

# %%
import platform # будем смотреть с помощью него данные о macOS

# %%
# Создаем словарь 
system_info = {
    "System" : platform.system(),
    "Release" : platform.release(),
    "Version" : platform.version(),
    "Machine" : platform.machine(),
    "Processor" : platform.processor()
}
# через цикл for выводим по строчно весь словарь
for key, value in system_info.items():
    print(f"{key} : {value}")
# Out:
# System : Darwin
# Release : 25.0.0
# Version : Darwin Kernel Version 25.0.0: Wed Sep 17 21:39:53 PDT 2025; root:xnu-12377.1.9~141/RELEASE_X86_64
# Machine : x86_64
# Processor : i386

# %%
import pandas as pd #положим словарь в таблицу>

# %%
# создаем базу, только вот она ключи преобразует в столбцы. По в выводе этой таблицы добавил функцию транспорнирования
df = pd.DataFrame([system_info])
df_t = df.T.rename(columns={0:'Поле1'})
print(df)
print('\n', df.T)
print('\n', df_t)
print('\n', df_t.loc['Version'])
version_list_one = list(df_t.loc['Version'])
version_list_two = list(df_t.loc['Version',:])
version_list_three = list(df_t.loc['Version','Поле1'])
print('\nversion_list_one: ', version_list_one)
print('\nversion_list_two: ', version_list_two)
print('\nversion_list_three: ', version_list_three)
# Out:
#    System Release                                            Version Machine  \
# 0  Darwin  25.0.0  Darwin Kernel Version 25.0.0: Wed Sep 17 21:39...  x86_64
#
#   Processor
# 0      i386
#
#                                                             0
# System                                                Darwin
# Release                                               25.0.0
# Version    Darwin Kernel Version 25.0.0: Wed Sep 17 21:39...
# Machine                                               x86_64
# Processor                                               i386
#
#                                                         Поле1
# System                                                Darwin
# Release                                               25.0.0
# Version    Darwin Kernel Version 25.0.0: Wed Sep 17 21:39...
# Machine                                               x86_64
# Processor                                               i386
#
# ...
